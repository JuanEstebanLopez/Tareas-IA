# %% [markdown]
# This game, as complex as it may seem, is still a zero-sum game of perfect information.
#
# The search space for this game can get really big really quickly, for example, in just a game of 3x3 dots:
#
# ````
#        1     2
#     O-----O-----O
#     |     |     |
#    3|    4|    5|
#     |  6  |  7  |
#     O-----O-----O
#     |     |     |
#   8 |    9|   10|
#     |     |     |
#     O-----O-----O
#        11    12
# ```
#
# There are 12 possible lines to be drawn. A game of 4x3 has 17 possibilities, a game of 4x4 has 24, etc. In general, a game consisting of a grid of **mxn** dots has *(m-1)n + m(n-1)* possible lines. This makes the resulting mini-max tree very large and it becomes necessary to prune it.
#
# Your assignment is to see how big a board you can make your AI play without each move taking too long (less than 1 minute)!
#
# As help, the following code defines the outline of your algorithm, all you need to do is to complete the **** functions and add the console interaction for the game.

# %%
DEPTH_LEVELS = 4
DISTANCE_LINES = 4

gameRows = -1
gameCols = -1

# Receives:
#   node: the current game state
#   player_symbol: the symbol chosen by the player
# Returns a pair (bool, symbol) representing if the game is over and which player (represented by a symbol) won
def is_game_over_dots(node, chosen_symbol):
    if None in node[0]:
        return False, None
    if node[1] == node[2]:
        return True, None
    elif node[1] > node[2]:
        return True, chosen_symbol
    else:
        return True, alternate_symbol_dots(chosen_symbol)

# Receives:
#   game_result: a pair returned from is_game_over_dots
#   node: current game state
#   is_maximizing_player_turn: a bool indicating if it's the turn of the maximizing player
# Returns a pair (number, node) representing the evaluation of the current board state depending on the current player
def evaluate_game_dots(game_result, node, is_maximizing_player_turn):
    val = node[2] - node[1]
    return val, node

# Receives:
#   node: current game state
#   chose_symbol: a character representing the current player
# Returns a list of nodes representing the possible moves to make for the current player in the current state
def generate_children_dots(node, chosen_symbol, is_machine):
    
    childrens_dots = []
    children_lines_index = set() # índices que se se van a validar
    
    # Genera las posibles jugadas que se pueden hacer (las que son máximo 2 casillas lejos de las existentes, las otras se ignoran ya que no afectan directamente)
    for line in range(len(node[0])):
        if node[0][line] is not None:
            nextLines = getNextsLines(line, DISTANCE_LINES,  gameRows, gameCols)
            
            children_lines_index =children_lines_index.union(nextLines)
    
    ch_list_inds = filter( lambda l_ind: node[0][l_ind] is None ,children_lines_index)
    #for x in ch_list_inds:
     #   print(x)
    for line in ch_list_inds:
        new_node = copy.deepcopy(node)
        new_node[0][line] = chosen_symbol
        index_turn = 2 if is_machine else 1
        new_node[index_turn] = new_node[index_turn] + check_box_complete(new_node, line, gameRows, gameCols)
        childrens_dots.append(new_node)
    
    #print(childrens_dots)
    return childrens_dots

# Receives:
#   symbol: a character representing a player
# Returns a pair (number, node) representing the evaluation of the current board state depending on the current player
def alternate_symbol_dots(symbol):
    return "+" if symbol == "-" else "-"

# Receives:
#    line: index of the line
#    rows: Total rows in the game 
#    cols: Total Columns in the game
# Return a pair (r, c) representing 
def getRowCol(line, rows, cols):
    cls = cols - 1
    rws = rows - 1
    tl = cls + cls + 1 # total lines for the first 2 rows
    
    r = int(line / tl) * 2
    c = line % tl
    if c >= cls: # Si es línea vertical
        c = c - cls
        r = r + 1
    return r, c

def getNextsLines(line, distance, rows, cols):
    
    nextLines = set()
    r, c = getRowCol(line, rows, cols)
    lim = ((cols-1)*rows + cols*(rows-1))
    isLineVertical = False if r % 2 == 0 else True
    
    for i in range(1, distance + 1):
        dis = 1 * i if isLineVertical else (cols * 2 - 1) * i
        
        sig = line + dis
        if sig < lim:
            nextLines.add(sig)
            
        ant = line - dis
        if ant >= 0:
            nextLines.add(ant)
        
    return nextLines


def mini_max_ab(node, is_maximizing_player_turn, chosen_symbol, alpha, beta, depth):
    game_result = is_game_over_dots(node, chosen_symbol)

    if depth == 0 or game_result[0]:
        return evaluate_game_dots(game_result, node, is_maximizing_player_turn)

    children = generate_children_dots(node, alternate_symbol_dots(chosen_symbol), is_maximizing_player_turn)
    
    if is_maximizing_player_turn:
        max_score = -1000000
        max_child = None

        for child in children:
            child_result = mini_max_ab(child, not is_maximizing_player_turn, alternate_symbol_dots(chosen_symbol), alpha, beta, depth - 1)

            if child_result[0] > max_score:
                max_child = child
                max_score = child_result[0]

            if child_result[0] > alpha:
                alpha = child_result[0]
            
            if beta <= alpha:
                break
                
        return max_score, max_child
    else:
        min_score = 1000000
        min_child = None

        for child in children:
            child_result = mini_max_ab(child, not is_maximizing_player_turn, alternate_symbol_dots(chosen_symbol), alpha, beta, depth - 1)

            if child_result[0] < min_score:
                min_child = child
                min_score = child_result[0]

            if child_result[0] < beta:
                beta = child_result[0]
            
            if beta <= alpha:
                break
            
        return min_score, min_child

# %% [markdown]
# # The game
#
# Below is a playable dots and boxes game that uses your implementation of the algorithm.

# %%
import re
import copy

DOT = 'O'
LINE_SIZE = 3

def get_size_input():
    print("Please input size of game as two space separated digits m (rows) and n (columns) larger than 1 (e.g. \"2 3\")")

    player_input = input()
    match = re.search("(\d{2,}|[2-9]) (\d{2,}|[2-9])", player_input.strip())

    if not match:
        print("Input is incorrect, try again")

        return get_size_input()
    else:
        return list(map(int, match.group().split()))
    
def get_odd_row(node, row, cols):
    [start, end] = [
        int(int((row/2)) * (2 * cols - 1) + cols - 1),
        int(int((row/2)) * (2 * cols - 1) + cols - 1 + cols)
    ]
    row_nodes = node[start:end]
    
    row = ""
    
    for col in range(2 * cols - 1):
        if col % 2 != 0:
            row = row + " " * LINE_SIZE
        else:
            head_symbol = row_nodes.pop(0)
            symbol = " " if head_symbol is None else head_symbol

            row = row + symbol
    
    return row

def get_even_row(node, row, cols):
    [start, end] = [
        int((row/2) * (2 * cols - 1)),
        int((row/2) * (2 * cols - 1) + cols - 1)
    ]
    row_nodes = node[start:end]
    
    row = ""
    
    for col in range(2 * cols - 1):
        if col % 2 == 0:
            row = row + DOT
        else:
            head_symbol = row_nodes.pop(0)
            symbol = " " if head_symbol is None else head_symbol
            
            row = row + symbol * LINE_SIZE
    
    return row

def print_node(node, rows, cols):
    rows_node = ""

    for row in range(2 * rows - 1):
        if row % 2 != 0: # Odd
            rows_node = rows_node + (get_odd_row(node[0], row, cols) + "\n") * LINE_SIZE
        else: # Even
            rows_node = rows_node + get_even_row(node[0], row, cols) + "\n"
    
    print(rows_node)
    print("Player score: " + str(node[1]))
    print("Machine score: " + str(node[2]))

def get_player_symbol():
    print("Please pick one of the following symbols: + or -")
    
    player_input = input()
    
    if player_input not in ["+", "-"]:
        print("Incorrect symbol, please try again")
        
        return get_player_symbol()
    else:
        return player_input

def check_vertical_box(node, line, cols):
    top_top = line - (2 * cols - 1)
    top_left = line - cols
    top_right = line - cols + 1
    top_bottom = line

    bottom_top = line
    bottom_left = line + cols - 1
    bottom_right = line + cols
    bottom_bottom = line + (2 * cols - 1)

    top_indices = [top_top, top_left, top_right, top_bottom]
    bottom_indices = [bottom_top, bottom_left, bottom_right, bottom_bottom]
        
    score = 0
    
    if min(top_indices) >= 0:
        top_symbols = [node[0][top_top], node[0][top_left], node[0][top_right], node[0][top_bottom]]
        
        if None not in top_symbols:
            score = score + 1
    if max(bottom_indices) < len(node[0]):
        bottom_symbols = [node[0][bottom_top], node[0][bottom_left], node[0][bottom_right], node[0][bottom_bottom]]

        if None not in bottom_symbols:
            score = score + 1
    
    return score

def check_horizontal_box(node, line, cols):
    left_top = line - cols
    left_left = line - 1
    left_right = line
    left_bottom = line + cols - 1

    right_top = line - cols + 1
    right_left = line
    right_right = line + 1
    right_bottom = line + cols

    left_indices = [left_top, left_left, left_right, left_bottom]
    right_indices = [right_top, right_left, right_right, right_bottom]
    
    score = 0
    
    if min(left_indices) >= 0:
        left_symbols = [node[0][left_top], node[0][left_left], node[0][left_right], node[0][left_bottom]]
        
        if None not in left_symbols:
            score = score + 1
    if max(right_indices) < len(node[0]):
        bottom_symbols = [node[0][right_top], node[0][right_left], node[0][right_right], node[0][right_bottom]]

        if None not in bottom_symbols:
            score = score + 1
    
    return score

def check_box_complete(node, line, rows, cols):
    row_num = -1
    
    for row in range(2 * rows - 1):
        start, end = -1, -1

        if row % 2 == 0:
            start, end = [
                int((row/2) * (2 * cols - 1)),
                int((row/2) * (2 * cols - 1) + cols - 1)
            ]
        else:
            start, end = [
                int(int((row/2)) * (2 * cols - 1) + cols - 1),
                int(int((row/2)) * (2 * cols - 1) + cols - 1 + cols)
            ]
        if start <= line < end:
            row_num = row
            break
    
    if row_num % 2 == 0:
        return check_vertical_box(node, line, cols)
    else:
        return check_horizontal_box(node, line, cols)

def player_turn(node, player_symbol, number_of_lines, rows, cols, player_input=None):
    print("Please chose a number between 0 and " + str(number_of_lines - 1) + ":")
    
    if player_input is None:
        player_input = input().strip()
    else: 
        player_input = "" + player_input
        
    match = re.search("\d+", player_input)
    new_node = copy.deepcopy(node)

    if not match:
        print("Input is not a number, please try again")
        
        return player_turn(node, player_symbol, number_of_lines, rows, cols)
    elif int(match.group()) < 0 or int(match.group()) > number_of_lines - 1:
        print("Number is not in the correct range, please try again")
        
        return player_turn(node, player_symbol, number_of_lines, rows, cols)
    elif new_node[0][int(match.group())] is not None:
        print("Line already taken, try again")

        return player_turn(node, player_symbol, number_of_lines, rows, cols)
    else:
        line = int(match.group())
        new_node[0][line] = player_symbol
        new_node[1] = new_node[1] + check_box_complete(new_node, line, rows, cols)
        
        r,c = getRowCol(line, rows, cols)
        print("Jugada en la fila {}, y columna {}".format(r, c))
        return new_node



    

    
    
def machine_turn(node, player_symbol, rows, cols): 
    
    
    evaluation, board = mini_max_ab(node, True, player_symbol, -1000000, 1000000, DEPTH_LEVELS)
    #print("---------------------------------------------------------------------------------")
    #print(evaluation, board)
    #print("---------------------------------------------------------------------------------")
    
    if board is not None:
        return board
    
    
    # TODO: This is where you should use your mini-max algorithm with alpha-beta pruning
    new_node = copy.deepcopy(node)
    
    for line in range(len(node[0])):
        if new_node[0][line] is None:
            new_node[0][line] = alternate_symbol_dots(player_symbol)
            new_node[2] = new_node[2] + check_box_complete(new_node, line, rows, cols)

            break
    
    return new_node








def play():
    [m, n] = get_size_input()
    
    global gameRows
    global gameCols

    gameRows = m
    gameCols = n
    
    number_of_lines = ((m-1)*n + m*(n-1))    
    node = [[None] * number_of_lines, 0, 0] # First element is lines drawn, second and third are player and machine scores respectively
    turns = number_of_lines

    player_symbol = get_player_symbol()
    
    is_player_turn = True

    print("\n\nEstado inicial del tablero:")
    print_node(node, m, n)

    while turns > 0:
        turns = turns - 1

        if is_player_turn:
            node = player_turn(node, player_symbol, number_of_lines, m, n)
        else:
            node = machine_turn(node, player_symbol, m, n)

        player = " (jugador)" if is_player_turn else " (maquina)"
        print("\n\nTurno # " + str(abs(turns - number_of_lines)) + player)
        print_node(node, m, n)
        
        is_player_turn = not is_player_turn
    print("Fin del juego")
    print()
play()
# Out:
# Please input size of game as two space separated digits m (rows) and n (columns) larger than 1 (e.g. "2 3")
# 9 9
# Please pick one of the following symbols: + or -
# -
#
#
# Estado inicial del tablero:
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
# Player score: 0
# Machine score: 0
# Please chose a number between 0 and 143:
# 140
# Jugada en la fila 16, y columna 4
#
#
# Turno # 1 (jugador)
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O---O   O   O   O
#
# Player score: 0
# Machine score: 0
#
#
# Turno # 2 (maquina)
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O---O   O   O   O
#
# Player score: 0
# Machine score: 0
# Please chose a number between 0 and 143:
# 139
# Jugada en la fila 16, y columna 3
#
#
# Turno # 3 (jugador)
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O---O---O   O   O   O
#
# Player score: 0
# Machine score: 0
#
#
# Turno # 4 (maquina)
# O   O   O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O---O---O   O   O   O
#
# Player score: 0
# Machine score: 0
# Please chose a number between 0 and 143:
# 137
# Jugada en la fila 16, y columna 1
#
#
# Turno # 5 (jugador)
# O   O   O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O   O---O---O   O   O   O
#
# Player score: 0
# Machine score: 0
#
#
# Turno # 6 (maquina)
# O   O   O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O   O---O---O   O   O   O
#
# Player score: 0
# Machine score: 0
# Please chose a number between 0 and 143:
# 120
# Jugada en la fila 14, y columna 1
#
#
# Turno # 7 (jugador)
# O   O   O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O   O   O   O   O   O   O
#
#
#
# O   O---O   O---O---O   O   O   O
#
# Player score: 0
# Machine score: 0
#
#
# Turno # 8 (maquina)
# O   O+++O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O   O   O   O   O   O   O
#
#
#
# O   O---O   O---O---O   O   O   O
#
# Player score: 0
# Machine score: 0
# Please chose a number between 0 and 143:
# 138
# Jugada en la fila 16, y columna 2
#
#
# Turno # 9 (jugador)
# O   O+++O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O   O   O   O   O   O   O
#
#
#
# O   O---O---O---O---O   O   O   O
#
# Player score: 0
# Machine score: 0
#
#
# Turno # 10 (maquina)
# O   O+++O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O   O   O   O   O   O   O
#
#
#
# O   O---O---O---O---O   O   O   O
#
# Player score: 0
# Machine score: 0
# Please chose a number between 0 and 143:
# 130
# Jugada en la fila 15, y columna 3
#
#
# Turno # 11 (jugador)
# O   O+++O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O   O   O   O   O   O   O
#             -
#             -
#             -
# O   O---O---O---O---O   O   O   O
#
# Player score: 0
# Machine score: 0
#
#
# Turno # 12 (maquina)
# O   O+++O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O   O   O   O   O   O   O
#     +       -
#     +       -
#     +       -
# O   O---O---O---O---O   O   O   O
#
# Player score: 0
# Machine score: 0
# Please chose a number between 0 and 143:
# 129
# Jugada en la fila 15, y columna 2
#
#
# Turno # 13 (jugador)
# O   O+++O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O   O   O   O   O   O   O
#     +   -   -
#     +   -   -
#     +   -   -
# O   O---O---O---O---O   O   O   O
#
# Player score: 1
# Machine score: 0
# Turno # 14 (maquina)
# O   O+++O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O   O   O   O   O   O
#     +   -   -
#     +   -   -
#     +   -   -
# O   O---O---O---O---O   O   O   O
#
# Player score: 1
# Machine score: 1
# Please chose a number between 0 and 143:
# 132
# Jugada en la fila 15, y columna 5
#
#
# Turno # 15 (jugador)
# O   O+++O   O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O   O   O   O   O   O
#     +   -   -       -
#     +   -   -       -
#     +   -   -       -
# O   O---O---O---O---O   O   O   O
#
# Player score: 1
# Machine score: 1
#
#
# Turno # 16 (maquina)
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O   O   O   O   O   O
#     +   -   -       -
#     +   -   -       -
#     +   -   -       -
# O   O---O---O---O---O   O   O   O
#
# Player score: 1
# Machine score: 1
# Please chose a number between 0 and 143:
# 131
# Jugada en la fila 15, y columna 4
#
#
# Turno # 17 (jugador)
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O   O   O   O   O   O
#     +   -   -   -   -
#     +   -   -   -   -
#     +   -   -   -   -
# O   O---O---O---O---O   O   O   O
#
# Player score: 1
# Machine score: 1
#
#
# Turno # 18 (maquina)
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O   O   O   O   O   O
#     +   -   -   -   -   +
#     +   -   -   -   -   +
#     +   -   -   -   -   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 1
# Machine score: 1
# Please chose a number between 0 and 143:
# 123
# Jugada en la fila 14, y columna 4
#
#
# Turno # 19 (jugador)
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O   O---O   O   O   O
#     +   -   -   -   -   +
#     +   -   -   -   -   +
#     +   -   -   -   -   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 1
#
#
# Turno # 20 (maquina)
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +
#     +   -   -   -   -   +
#     +   -   -   -   -   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 2
# Please chose a number between 0 and 143:
# 50
# Jugada en la fila 5, y columna 8
#
#
# Turno # 21 (jugador)
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +
#     +   -   -   -   -   +
#     +   -   -   -   -   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 2
#
#
# Turno # 22 (maquina)
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 2
# Please chose a number between 0 and 143:
# 15
# Jugada en la fila 1, y columna 7
#
#
# Turno # 23 (jugador)
# O   O+++O+++O   O+++O   O   O   O
#                             -
#                             -
#                             -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 2
#
#
# Turno # 24 (maquina)
# O   O+++O+++O   O+++O   O   O   O
#             +               -
#             +               -
#             +               -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 2
# Please chose a number between 0 and 143:
# 25
# Jugada en la fila 3, y columna 0
#
#
# Turno # 25 (jugador)
# O   O+++O+++O   O+++O   O   O   O
#             +               -
#             +               -
#             +               -
# O   O   O   O   O   O   O   O   O
# -
# -
# -
# O   O   O   O   O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 2
#
#
# Turno # 26 (maquina)
# O   O+++O+++O   O+++O   O   O+++O
#             +               -
#             +               -
#             +               -
# O   O   O   O   O   O   O   O   O
# -
# -
# -
# O   O   O   O   O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 2
# Please chose a number between 0 and 143:
# 37
# Jugada en la fila 4, y columna 3
#
#
# Turno # 27 (jugador)
# O   O+++O+++O   O+++O   O   O+++O
#             +               -
#             +               -
#             +               -
# O   O   O   O   O   O   O   O   O
# -
# -
# -
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 2
# Turno # 28 (maquina)
# O   O+++O+++O+++O+++O   O   O+++O
#             +               -
#             +               -
#             +               -
# O   O   O   O   O   O   O   O   O
# -
# -
# -
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 2
# Please chose a number between 0 and 143:
# 70
# Line already taken, try again
# Please chose a number between 0 and 143:
# 11
# Line already taken, try again
# Please chose a number between 0 and 143:
# 12
# Jugada en la fila 1, y columna 4
#
#
# Turno # 29 (jugador)
# O   O+++O+++O+++O+++O   O   O+++O
#             +   -           -
#             +   -           -
#             +   -           -
# O   O   O   O   O   O   O   O   O
# -
# -
# -
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 2
#
#
# Turno # 30 (maquina)
# O   O+++O+++O+++O+++O   O   O+++O
#             +   -           -
#             +   -           -
#             +   -           -
# O   O   O   O+++O   O   O   O   O
# -
# -
# -
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 3
# Please chose a number between 0 and 143:
# 14
# Jugada en la fila 1, y columna 6
#
#
# Turno # 31 (jugador)
# O   O+++O+++O+++O+++O   O   O+++O
#             +   -       -   -
#             +   -       -   -
#             +   -       -   -
# O   O   O   O+++O   O   O   O   O
# -
# -
# -
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 3
#
#
# Turno # 32 (maquina)
# O   O+++O+++O+++O+++O   O   O+++O
# +           +   -       -   -
# +           +   -       -   -
# +           +   -       -   -
# O   O   O   O+++O   O   O   O   O
# -
# -
# -
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 3
# Please chose a number between 0 and 143:
# 17
# Jugada en la fila 2, y columna 0
#
#
# Turno # 33 (jugador)
# O   O+++O+++O+++O+++O   O   O+++O
# +           +   -       -   -
# +           +   -       -   -
# +           +   -       -   -
# O---O   O   O+++O   O   O   O   O
# -
# -
# -
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 3
#
#
# Turno # 34 (maquina)
# O   O+++O+++O+++O+++O+++O   O+++O
# +           +   -       -   -
# +           +   -       -   -
# +           +   -       -   -
# O---O   O   O+++O   O   O   O   O
# -
# -
# -
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 3
# Please chose a number between 0 and 143:
# 18
# Jugada en la fila 2, y columna 1
#
#
# Turno # 35 (jugador)
# O   O+++O+++O+++O+++O+++O   O+++O
# +           +   -       -   -
# +           +   -       -   -
# +           +   -       -   -
# O---O---O   O+++O   O   O   O   O
# -
# -
# -
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 3
#
#
# Turno # 36 (maquina)
# O   O+++O+++O+++O+++O+++O   O+++O
# +           +   -       -   -   +
# +           +   -       -   -   +
# +           +   -       -   -   +
# O---O---O   O+++O   O   O   O   O
# -
# -
# -
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 4
# Please chose a number between 0 and 143:
# 19
# Jugada en la fila 2, y columna 2
#
#
# Turno # 37 (jugador)
# O   O+++O+++O+++O+++O+++O   O+++O
# +           +   -       -   -   +
# +           +   -       -   -   +
# +           +   -       -   -   +
# O---O---O---O+++O   O   O   O   O
# -
# -
# -
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 4
#
#
# Turno # 38 (maquina)
# O   O+++O+++O+++O+++O+++O   O+++O
# +       +   +   -       -   -   +
# +       +   +   -       -   -   +
# +       +   +   -       -   -   +
# O---O---O---O+++O   O   O   O   O
# -
# -
# -
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 2
# Machine score: 5
# Please chose a number between 0 and 143:
# 24
# Jugada en la fila 2, y columna 7
#
#
# Turno # 39 (jugador)
# O   O+++O+++O+++O+++O+++O   O+++O
# +       +   +   -       -   -   +
# +       +   +   -       -   -   +
# ...
# Machine score: 7
#
#
# Turno # 52 (maquina)
# O---O+++O+++O+++O+++O+++O   O+++O
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# O---O---O---O+++O---O+++O   O---O
# -   +   +           +       +
# -   +   +           +       +
# -   +   +           +       +
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#                 -
#                 -
#                 -
# O   O   O   O   O   O   O   O   O
#                 -               -
#                 -               -
#                 -               -
# O---O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 5
# Machine score: 7
# Please chose a number between 0 and 143:
# 27
# Line already taken, try again
# Please chose a number between 0 and 143:
# 28
# Jugada en la fila 3, y columna 3
#
#
# Turno # 53 (jugador)
# O---O+++O+++O+++O+++O+++O   O+++O
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# O---O---O---O+++O---O+++O   O---O
# -   +   +   -       +       +
# -   +   +   -       +       +
# -   +   +   -       +       +
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#                 -
#                 -
#                 -
# O   O   O   O   O   O   O   O   O
#                 -               -
#                 -               -
#                 -               -
# O---O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 5
# Machine score: 7
#
#
# Turno # 54 (maquina)
# O---O+++O+++O+++O+++O+++O   O+++O
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# O---O---O---O+++O---O+++O   O---O
# -   +   +   -   +   +       +
# -   +   +   -   +   +       +
# -   +   +   -   +   +       +
# O   O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#                 -
#                 -
#                 -
# O   O   O   O   O   O   O   O   O
#                 -               -
#                 -               -
#                 -               -
# O---O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 5
# Machine score: 8
# Please chose a number between 0 and 143:
# 34
# Jugada en la fila 4, y columna 0
#
#
# Turno # 55 (jugador)
# O---O+++O+++O+++O+++O+++O   O+++O
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# O---O---O---O+++O---O+++O   O---O
# -   +   +   -   +   +       +
# -   +   +   -   +   +       +
# -   +   +   -   +   +       +
# O---O   O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#                 -
#                 -
#                 -
# O   O   O   O   O   O   O   O   O
#                 -               -
#                 -               -
#                 -               -
# O---O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 6
# Machine score: 8
# Turno # 56 (maquina)
# O---O+++O+++O+++O+++O+++O   O+++O
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# O---O---O---O+++O---O+++O   O---O
# -   +   +   -   +   +       +
# -   +   +   -   +   +       +
# -   +   +   -   +   +       +
# O---O+++O   O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#                 -
#                 -
#                 -
# O   O   O   O   O   O   O   O   O
#                 -               -
#                 -               -
#                 -               -
# O---O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 6
# Machine score: 9
# Please chose a number between 0 and 143:
# 36
# Jugada en la fila 4, y columna 2
#
#
# Turno # 57 (jugador)
# O---O+++O+++O+++O+++O+++O   O+++O
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# O---O---O---O+++O---O+++O   O---O
# -   +   +   -   +   +       +
# -   +   +   -   +   +       +
# -   +   +   -   +   +       +
# O---O+++O---O---O   O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#                 -
#                 -
#                 -
# O   O   O   O   O   O   O   O   O
#                 -               -
#                 -               -
#                 -               -
# O---O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 7
# Machine score: 9
#
#
# Turno # 58 (maquina)
# O---O+++O+++O+++O+++O+++O   O+++O
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# O---O---O---O+++O---O+++O   O---O
# -   +   +   -   +   +       +
# -   +   +   -   +   +       +
# -   +   +   -   +   +       +
# O---O+++O---O---O+++O   O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#                 -
#                 -
#                 -
# O   O   O   O   O   O   O   O   O
#                 -               -
#                 -               -
#                 -               -
# O---O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 7
# Machine score: 10
# Please chose a number between 0 and 143:
# 39
# Jugada en la fila 4, y columna 5
#
#
# Turno # 59 (jugador)
# O---O+++O+++O+++O+++O+++O   O+++O
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# O---O---O---O+++O---O+++O   O---O
# -   +   +   -   +   +       +
# -   +   +   -   +   +       +
# -   +   +   -   +   +       +
# O---O+++O---O---O+++O---O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#                 -
#                 -
#                 -
# O   O   O   O   O   O   O   O   O
#                 -               -
#                 -               -
#                 -               -
# O---O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 7
# Machine score: 10
#
#
# Turno # 60 (maquina)
# O---O+++O+++O+++O+++O+++O   O+++O
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# O---O---O---O+++O---O+++O   O---O
# -   +   +   -   +   +   +   +
# -   +   +   -   +   +   +   +
# -   +   +   -   +   +   +   +
# O---O+++O---O---O+++O---O   O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#                 -
#                 -
#                 -
# O   O   O   O   O   O   O   O   O
#                 -               -
#                 -               -
#                 -               -
# O---O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 7
# Machine score: 11
# Please chose a number between 0 and 143:
# 39
# Line already taken, try again
# Please chose a number between 0 and 143:
# 40
# Jugada en la fila 4, y columna 6
#
#
# Turno # 61 (jugador)
# O---O+++O+++O+++O+++O+++O   O+++O
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# O---O---O---O+++O---O+++O   O---O
# -   +   +   -   +   +   +   +
# -   +   +   -   +   +   +   +
# -   +   +   -   +   +   +   +
# O---O+++O---O---O+++O---O---O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#                 -
#                 -
#                 -
# O   O   O   O   O   O   O   O   O
#                 -               -
#                 -               -
#                 -               -
# O---O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 7
# Machine score: 11
#
#
# Turno # 62 (maquina)
# O---O+++O+++O+++O+++O+++O   O+++O
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# O---O---O---O+++O---O+++O+++O---O
# -   +   +   -   +   +   +   +
# -   +   +   -   +   +   +   +
# -   +   +   -   +   +   +   +
# O---O+++O---O---O+++O---O---O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#                 -
#                 -
#                 -
# O   O   O   O   O   O   O   O   O
#                 -               -
#                 -               -
#                 -               -
# O---O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 7
# Machine score: 12
# Please chose a number between 0 and 143:
# 6
# Jugada en la fila 0, y columna 6
#
#
# Turno # 63 (jugador)
# O---O+++O+++O+++O+++O+++O---O+++O
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# O---O---O---O+++O---O+++O+++O---O
# -   +   +   -   +   +   +   +
# -   +   +   -   +   +   +   +
# -   +   +   -   +   +   +   +
# O---O+++O---O---O+++O---O---O   O
#                                 -
#                                 -
#                                 -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#                 -
#                 -
#                 -
# O   O   O   O   O   O   O   O   O
#                 -               -
#                 -               -
#                 -               -
# O---O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 8
# Machine score: 12
#
#
# Turno # 64 (maquina)
# O---O+++O+++O+++O+++O+++O---O+++O
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# +   +   +   +   -   +   -   -   +
# O---O---O---O+++O---O+++O+++O---O
# -   +   +   -   +   +   +   +
# -   +   +   -   +   +   +   +
# -   +   +   -   +   +   +   +
# O---O+++O---O---O+++O---O---O   O
#                 +               -
#                 +               -
#                 +               -
# O   O   O   O   O   O   O   O   O
#
#
#
# O   O+++O+++O   O+++O   O   O   O
#                 -
#                 -
#                 -
# O   O   O   O   O   O   O   O   O
#                 -               -
#                 -               -
#                 -               -
# O---O   O   O   O   O   O   O   O
#
#
#
# O   O---O+++O+++O---O   O   O   O
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
#     +   -   -   -   -   +   +
# O   O---O---O---O---O   O   O   O
#
# Player score: 8
# Machine score: 12
# Please chose a number between 0 and 143:
